# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import re # Regular expressions

# --- Configuratie ---
BASE_URL = "https://www.zorgkaartnederland.nl"
TARGET_REGION = "nijmegen" # OF "arnhem"

if TARGET_REGION == "arnhem":
    START_PATH = "/verpleeghuis-en-verzorgingshuis/arnhem"
    OUTPUT_FILE = "zorginstellingen_arnhem_w_beds_pc.json" # Aangepaste output naam
    REGION = "Arnhem"
elif TARGET_REGION == "nijmegen":
    START_PATH = "/verpleeghuis-en-verzorgingshuis/nijmegen"
    OUTPUT_FILE = "zorginstellingen_nijmegen_w_beds_pc.json" # Aangepaste output naam
    REGION = "Nijmegen"
else:
    print(f"Fout: Onbekende TARGET_REGION '{TARGET_REGION}'. Kies 'arnhem' of 'nijmegen'.")
    exit()

PARAMS = "?d=25"
MAX_PAGES = 10
REQUEST_TIMEOUT = 15
PAUSE_BETWEEN_PAGES = 2
PAUSE_BETWEEN_ITEMS = 0.7

HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'nl-NL,nl;q=0.9,en-US;q=0.8,en;q=0.7',
    'Referer': BASE_URL + '/'
}

# --- CSS Selectors ---
selectors = {
    "result_item": "div.filter-result",
    "name": "a.filter-result__name",
    "places": "div.filter-result__places",
    "distance": "div.filter-result__places span.badge",
    "rating_score": "div.filter-result__score",
    "rating_count_container": "div.filter-result__body__right p",
    "facilities_link": "a.tab-link:contains('Faciliteiten')",
    "facilities_table": "table.table-no-borders",
    "facilities_table_row": "tr.row.mx-0"
}
# ------------------------------------------------------------------------------------

def parse_rating_count(text):
    """Probeert het aantal waarderingen uit een tekst te halen."""
    if not text: return None
    match = re.search(r'\d+', text)
    return int(match.group(0)) if match else None

def get_aantal_plaatsen_totaal(item_url, session):
    """
    Haalt het totaal aantal plaatsen EN de postcode op van de detail/faciliteitenpagina.
    Retourneert een tuple (count, postcode), waarbij elk None kan zijn.
    """
    postcode = None # Initialize postcode variable
    count = None    # Initialize count variable

    try:
        # 1. Haal detailpagina op
        print(f"  -> Detailpagina ophalen: {item_url}")
        detail_response = session.get(item_url, timeout=REQUEST_TIMEOUT)
        detail_response.raise_for_status()
        detail_soup = BeautifulSoup(detail_response.text, 'html.parser')

        # === NIEUW: Extraheer Postcode uit JSON-LD ===
        script_tag = detail_soup.find('script', type='application/ld+json')
        if script_tag and script_tag.string:
            try:
                ld_json_data = json.loads(script_tag.string)
                address_data = ld_json_data.get('address', {}) # Gebruik .get met default {}
                postcode = address_data.get('postalCode') # Geeft None terug als key niet bestaat
                if postcode:
                    print(f"  -> Gevonden postcode (JSON-LD): {postcode}")
                else:
                    print(f"  -> Waarschuwing: 'postalCode' niet gevonden in JSON-LD adres op {item_url}")
            except json.JSONDecodeError as json_err:
                print(f"  -> Fout: Kon JSON-LD niet parsen op {item_url}: {json_err}")
            except Exception as e:
                 print(f"  -> Fout: Onverwachte fout bij verwerken JSON-LD op {item_url}: {e}")
        else:
            print(f"  -> Waarschuwing: JSON-LD script tag niet gevonden op {item_url}")
        # === EINDE: Extractie Postcode ===


        # 2. Zoek 'Faciliteiten' link
        faciliteiten_link = detail_soup.find(
            'a',
            class_='tab-link',
            string=lambda t: t and 'Faciliteiten' in t.strip()
        )

        if not faciliteiten_link or not faciliteiten_link.has_attr('href'):
            print(f"  -> 'Faciliteiten' link niet gevonden op {item_url}. Kan aantal plaatsen niet ophalen.")
            return count, postcode # <<< Retourneer (None, mogelijk gevonden postcode)

        faciliteiten_path = faciliteiten_link['href']
        if faciliteiten_path.startswith('/'):
            faciliteiten_url = BASE_URL + faciliteiten_path
        elif not faciliteiten_path.startswith(('http:', 'https:')):
             print(f"  -> Waarschuwing: onverwacht formaat faciliteiten href: {faciliteiten_path}")
             faciliteiten_url = BASE_URL + "/" + faciliteiten_path.lstrip('/')
        else:
             faciliteiten_url = faciliteiten_path

        # 3. Haal faciliteitenpagina op
        print(f"  -> Faciliteitenpagina ophalen: {faciliteiten_url}")
        faciliteiten_response = session.get(faciliteiten_url, timeout=REQUEST_TIMEOUT)
        faciliteiten_response.raise_for_status()
        faciliteiten_soup = BeautifulSoup(faciliteiten_response.text, 'html.parser')

        # 4. Zoek de tabel(len) en de specifieke rij voor aantal plaatsen
        target_tables = faciliteiten_soup.select(selectors["facilities_table"])
        if not target_tables:
            print(f"  -> Geen tabel(len) met class 'table-no-borders' gevonden op faciliteitenpagina: {faciliteiten_url}")
            return count, postcode # <<< Retourneer (None, mogelijk gevonden postcode)

        found_count = False
        for target_table in target_tables:
             heading = target_table.find_previous_sibling('h3')
             if heading and "Aantal plekken en wachttijd" in heading.get_text(strip=True):
                  print(f"  -> Correcte tabel gevonden ('Aantal plekken en wachttijd').")
                  rows = target_table.select(selectors["facilities_table_row"])
                  for row in rows:
                      header = row.select_one('th.col-6')
                      value_cell = row.select_one('td.col-6')

                      if header and value_cell and "Aantal plaatsen totaal" == header.get_text(strip=True):
                          try:
                              count = int(value_cell.get_text(strip=True)) # Update count variabele
                              found_count = True
                              print(f"  -> Gevonden aantal plaatsen totaal: {count}")
                              # Ga NIET meteen returnen, controleer eerst alle tabellen
                              break # Stop met zoeken in deze tabel
                          except ValueError:
                              print(f"  -> Fout: Kon waarde '{value_cell.get_text(strip=True)}' niet converteren naar getal.")
                              count = None # Fout bij conversie, zet count op None
                              found_count = True # Markeer dat we de rij wel vonden
                              break # Stop met zoeken in deze tabel
                  if found_count:
                        break # Stop met zoeken door tabellen als we de rij hebben verwerkt
        # Einde tabel loop

        if not found_count:
             print(f"  -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.")
             # Count blijft None als het niet gevonden is

        # Retourneer de gevonden (of None) waarden aan het einde
        return count, postcode

    except requests.exceptions.Timeout:
        print(f"  -> Fout: Timeout bij ophalen van {item_url} of faciliteitenpagina.")
        return count, postcode # Retourneer wat we eventueel al hadden
    except requests.exceptions.RequestException as e:
        print(f"  -> Fout: Netwerkfout tijdens ophalen details/faciliteiten voor {item_url}: {e}")
        return count, postcode # Retourneer wat we eventueel al hadden
    except Exception as e:
        print(f"  -> Fout: Onverwachte fout bij verwerken {item_url}: {e}")
        return None, None # In dit geval weten we niks zeker

def scrape_zorgkaart():
    all_data = []
    session = requests.Session()
    session.headers.update(HEADERS)

    print(f"Starten met scrapen van ZorgkaartNederland voor regio: {REGION}...")
    print(f"Output wordt opgeslagen in: {OUTPUT_FILE}")
    print(f"Pauze tussen pagina's: {PAUSE_BETWEEN_PAGES}s, Pauze tussen items: {PAUSE_BETWEEN_ITEMS}s")

    for page_num in range(1, MAX_PAGES + 1):
        print(f"\n--- Scraping pagina {page_num} voor {REGION} ---")

        if page_num == 1:
            page_path = START_PATH + PARAMS
        else:
            page_path = f"{START_PATH}/pagina{page_num}{PARAMS}"

        current_url = BASE_URL + page_path
        print(f"Pagina URL: {current_url}")

        try:
            response = session.get(current_url, timeout=REQUEST_TIMEOUT)
            response.raise_for_status()

            soup = BeautifulSoup(response.text, 'html.parser')
            results = soup.select(selectors["result_item"])

            if not results:
                print(f"Geen resultaten (items) meer gevonden op pagina {page_num}. Stoppen met pagineren.")
                break

            print(f"Aantal resultaten gevonden op deze pagina: {len(results)}")

            for index, item in enumerate(results):
                print(f"\nVerwerken item {index + 1}/{len(results)} op pagina {page_num}...")
                data = {"Regio": REGION}

                # --- Basisgegevens extractie ---
                name_element = item.select_one(selectors["name"])
                data["Naam"] = name_element.get_text(strip=True) if name_element else None
                item_url = BASE_URL + name_element['href'] if name_element and name_element.has_attr('href') else None
                data["Url"] = item_url

                distance_element = item.select_one(selectors["distance"])
                distance_text = distance_element.get_text(strip=True) if distance_element else None
                data["Afstand"] = distance_text

                places_element = item.select_one(selectors["places"])
                if places_element:
                    full_places_text = places_element.get_text(strip=True)
                    location_text = full_places_text.replace(distance_text, '').strip() if distance_text else full_places_text
                    data["Locatie"] = re.sub(r'\s+', ' ', location_text).strip('() ')
                else:
                    data["Locatie"] = None

                rating_score_element = item.select_one(selectors["rating_score"])
                data["Cijfer"] = None
                if rating_score_element:
                    rating_text = rating_score_element.get_text(strip=True).replace(',', '.')
                    try:
                        data["Cijfer"] = float(rating_text)
                    except ValueError:
                        print(f"  - Waarschuwing: Kon cijfer '{rating_text}' niet converteren voor {data.get('Naam')}.")
                        pass

                rating_count_container = item.select_one(selectors["rating_count_container"])
                rating_count_text = rating_count_container.get_text(strip=True) if rating_count_container else None
                data["Aantal Waarderingen"] = parse_rating_count(rating_count_text)

                # --- Haal aantal plaatsen totaal EN postcode op ---
                data["Aantal Plaatsen Totaal"] = None # Standaardwaarde
                data["Postcode"] = None              # Standaardwaarde voor postcode

                if item_url:
                    # === AANGEPAST: Unpack het tuple ===
                    totaal_count, postcode_val = get_aantal_plaatsen_totaal(item_url, session)
                    data["Aantal Plaatsen Totaal"] = totaal_count
                    data["Postcode"] = postcode_val # Wijs de mogelijk gevonden postcode toe
                else:
                    print(f"  - Waarschuwing: Geen URL gevonden voor item, kan details niet ophalen.")


                # --- Voeg data toe aan lijst ---
                if data["Naam"]:
                     # === AANGEPAST: Log message met postcode ===
                    print(f"  -> Data verzameld voor: {data['Naam']} (Plaatsen: {data.get('Aantal Plaatsen Totaal', 'N/B')}, Postcode: {data.get('Postcode', 'N/B')})")
                    all_data.append(data)
                else:
                    print(f"  - Waarschuwing: Item overgeslagen op pagina {page_num} wegens ontbrekende naam.")

                time.sleep(PAUSE_BETWEEN_ITEMS) # Pauze

            if page_num < MAX_PAGES:
                print(f"\nEinde pagina {page_num}, pauzeren ({PAUSE_BETWEEN_PAGES}s)...")
                time.sleep(PAUSE_BETWEEN_PAGES)

        except requests.exceptions.Timeout:
            print(f"Fout: Timeout bij ophalen van hoofdpagina {current_url}. Stoppen.")
            break
        except requests.exceptions.RequestException as e:
            print(f"Fout: Netwerkfout bij ophalen {current_url}: {e}. Stoppen.")
            break
        except Exception as e:
            print(f"Fout: Onverwachte fout tijdens parsen pagina {page_num}: {e}")
            print("Proberen door te gaan naar volgende pagina (indien mogelijk)...")
            time.sleep(PAUSE_BETWEEN_PAGES)
            continue

    return all_data

if __name__ == "__main__":
    try:
        import requests
        from bs4 import BeautifulSoup
    except ImportError:
        print("="*60); print("FOUT: Libraries 'requests' en/of 'beautifulsoup4' niet geïnstalleerd."); print("Installeer ze met: pip install requests beautifulsoup4"); print("="*60); exit(1)

    start_time = time.time()
    scraped_data = scrape_zorgkaart()
    end_time = time.time()

    print("\n" + "="*60); print(f"Scrapen voltooid in {end_time - start_time:.2f} seconden."); print(f"Totaal {len(scraped_data)} instellingen gevonden en verwerkt voor {REGION}."); print("="*60)

    if scraped_data:
        try:
            with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
                json.dump(scraped_data, f, ensure_ascii=False, indent=4)
            print(f"\nData succesvol opgeslagen in bestand: {OUTPUT_FILE}")
        except IOError as e:
            print(f"\nFout: Kon niet schrijven naar bestand {OUTPUT_FILE}: {e}")
        except Exception as e:
            print(f"\nFout: Onverwachte fout bij opslaan JSON: {e}")
    else:
        print("\nGeen data gescraped. Controleer selectors, URL, website beschikbaarheid en foutmeldingen hierboven.")
# Out:
# Starten met scrapen van ZorgkaartNederland voor regio: Nijmegen...
# Output wordt opgeslagen in: zorginstellingen_nijmegen_w_beds_pc.json
# Pauze tussen pagina's: 2s, Pauze tussen items: 0.7s
#
# --- Scraping pagina 1 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen?d=25
# Aantal resultaten gevonden op deze pagina: 20
#
# Verwerken item 1/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sint-jozef-lent-lent-12650
#   -> Gevonden postcode (JSON-LD): 6663 CP
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sint-jozef-lent-lent-12650/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: RijnWaal Zorggroep, locatie Sint Jozef Lent (Plaatsen: None, Postcode: 6663 CP)
#
# Verwerken item 2/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-quarijn-de-linde-achterberg-10015768
#   -> Gevonden postcode (JSON-LD): 3911 XS
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-quarijn-de-linde-achterberg-10015768. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: QuaRijn, De Linde (Plaatsen: None, Postcode: 3911 XS)
#
# Verwerken item 3/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-kastanjehof-velp-3048026
#   -> Gevonden postcode (JSON-LD): 6883 JR
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-kastanjehof-velp-3048026. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Attent Zorg en Behandeling, Kastanjehof (Plaatsen: None, Postcode: 6883 JR)
#
# Verwerken item 4/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-tertzio-elst-12569
#   -> Gevonden postcode (JSON-LD): 6661 CP
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-tertzio-elst-12569/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Attent Zorg en Behandeling, Tertzio (Plaatsen: None, Postcode: 6661 CP)
#
# Verwerken item 5/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-meerstaete-wijchen-3063264
#   -> Gevonden postcode (JSON-LD): 6602 GX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-meerstaete-wijchen-3063264/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 27
#   -> Data verzameld voor: ZZG Zorggroep, Woonlocatie Meerstaete (Plaatsen: 27, Postcode: 6602 GX)
#
# Verwerken item 6/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-groesbeek-33026
#   -> Gevonden postcode (JSON-LD): 6561 LE
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-groesbeek-33026. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: ZZG zorggroep (Plaatsen: None, Postcode: 6561 LE)
#
# Verwerken item 7/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-kesteren-10085306
#   -> Gevonden postcode (JSON-LD): 4041 CA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-kesteren-10085306. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Zorgcentrum Anker (Plaatsen: None, Postcode: 4041 CA)
#
# Verwerken item 8/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-locatie-anker-kesteren-12648
#   -> Gevonden postcode (JSON-LD): 4041 CA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-locatie-anker-kesteren-12648/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Zorgcentrum Anker, locatie Anker (Plaatsen: None, Postcode: 4041 CA)
#
# Verwerken item 9/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgresidence-regina-velp-12710
#   -> Gevonden postcode (JSON-LD): 6881 NC
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgresidence-regina-velp-12710/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 29
#   -> Data verzameld voor: Zorgresidence Regina (Plaatsen: 29, Postcode: 6881 NC)
#
# Verwerken item 10/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sint-jozef-gendt-gendt-12625
#   -> Gevonden postcode (JSON-LD): 6691 CX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sint-jozef-gendt-gendt-12625/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: RijnWaal Zorggroep, locatie Sint Jozef Gendt (Plaatsen: None, Postcode: 6691 CX)
#
# Verwerken item 11/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-hoogstede-arnhem-10000294
#   -> Gevonden postcode (JSON-LD): 6812 AG
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-hoogstede-arnhem-10000294/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 52
#   -> Data verzameld voor: DrieGasthuizenGroep, Woonzorgcentrum Hoogstede (Plaatsen: 52, Postcode: 6812 AG)
#
# Verwerken item 12/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-de-schittering-haps-3041801
#   -> Gevonden postcode (JSON-LD): 5443 AR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-de-schittering-haps-3041801/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein De Schittering (Plaatsen: None, Postcode: 5443 AR)
#
# Verwerken item 13/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-gendt-31276
#   -> Gevonden postcode (JSON-LD): 6691 CX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-gendt-31276/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: RijnWaal Zorggroep (Plaatsen: None, Postcode: 6691 CX)
#
# Verwerken item 14/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-regina-pacis-arnhem-14668
#   -> Gevonden postcode (JSON-LD): 6824 MD
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-regina-pacis-arnhem-14668/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Attent Zorg en Behandeling, Regina Pacis (Plaatsen: None, Postcode: 6824 MD)
#
# Verwerken item 15/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sancta-maria-huissen-12645
#   -> Gevonden postcode (JSON-LD): 6851 CC
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-rijnwaal-zorggroep-locatie-sancta-maria-huissen-12645/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: RijnWaal Zorggroep, locatie Sancta Maria (Plaatsen: None, Postcode: 6851 CC)
#
# Verwerken item 16/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-oss-12232
#   -> Gevonden postcode (JSON-LD): 5349 AA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-oss-12232. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: BrabantZorg (Plaatsen: None, Postcode: 5349 AA)
#
# Verwerken item 17/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-doorwerth-11874
#   -> Gevonden postcode (JSON-LD): 6865 CK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-doorwerth-11874/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Vilente (Plaatsen: None, Postcode: 6865 CK)
#
# Verwerken item 18/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-proteion-zorgcentrum-libermannhof-gennep-13565
#   -> Gevonden postcode (JSON-LD): 6591 GT
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-proteion-zorgcentrum-libermannhof-gennep-13565. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Proteion Zorgcentrum Libermannhof (Plaatsen: None, Postcode: 6591 GT)
#
# Verwerken item 19/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-de-wellen-oss-14888
#   -> Gevonden postcode (JSON-LD): 5341 AL
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-de-wellen-oss-14888/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, De Wellen (Plaatsen: None, Postcode: 5341 AL)
#
# Verwerken item 20/20 op pagina 1...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-zorgcentrum-andalhof-andelst-10020734
#   -> Gevonden postcode (JSON-LD): 6673 BC
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-zorgcentrum-andalhof-andelst-10020734/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Stichting Samen Zorgen, Zorgcentrum Andalhof (Plaatsen: None, Postcode: 6673 BC)
#
# Einde pagina 1, pauzeren (2s)...
#
# --- Scraping pagina 2 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina2?d=25
# Aantal resultaten gevonden op deze pagina: 20
#
# Verwerken item 1/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-de-meridiaan-westervoort-3041814
#   -> Gevonden postcode (JSON-LD): 6932 MX
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-de-meridiaan-westervoort-3041814. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, De Meridiaan (Plaatsen: None, Postcode: 6932 MX)
#
# Verwerken item 2/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-de-boomgaard-rheden-15363
#   -> Gevonden postcode (JSON-LD): 6991 CT
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-attent-zorg-en-behandeling-de-boomgaard-rheden-15363/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Attent Zorg en Behandeling, De Boomgaard (Plaatsen: None, Postcode: 6991 CT)
#
# Verwerken item 3/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-pieter-pauw-wageningen-14693
#   -> Gevonden postcode (JSON-LD): 6702 AA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-pieter-pauw-wageningen-14693/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 90
#   -> Data verzameld voor: Vilente Pieter Pauw (Plaatsen: 90, Postcode: 6702 AA)
#
# Verwerken item 4/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-de-honinghoeve-nijmegen-12667
#   -> Gevonden postcode (JSON-LD): 6544 RA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-de-honinghoeve-nijmegen-12667/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 113
#   -> Data verzameld voor: De Waalboog, locatie De Honinghoeve (Plaatsen: 113, Postcode: 6544 RA)
#
# Verwerken item 5/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-kalorama-beek-ubbergen-11865
#   -> Gevonden postcode (JSON-LD): 6573 DX
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-kalorama-beek-ubbergen-11865. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Kalorama (Plaatsen: None, Postcode: 6573 DX)
#
# Verwerken item 6/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-thuvine-duiven-12605
#   -> Gevonden postcode (JSON-LD): 6921 AR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-thuvine-duiven-12605/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pleyade, locatie Thuvine (Plaatsen: None, Postcode: 6921 AR)
#
# Verwerken item 7/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-huize-rosa-nijmegen-12674
#   -> Gevonden postcode (JSON-LD): 6543 JG
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-huize-rosa-nijmegen-12674/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Zorgcentrum Huize Rosa (Plaatsen: None, Postcode: 6543 JG)
#
# Verwerken item 8/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-catharinahof-grave-3053827
#   -> Gevonden postcode (JSON-LD): 5361 CR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-catharinahof-grave-3053827/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, Catharinahof (Plaatsen: None, Postcode: 5361 CR)
#
# Verwerken item 9/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-beneden-leeuwen-11866
#   -> Gevonden postcode (JSON-LD): 6658 WX
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-beneden-leeuwen-11866. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: zorggroep Maas en Waal (Plaatsen: None, Postcode: 6658 WX)
#
# Verwerken item 10/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-arnhem-11858
#   -> Gevonden postcode (JSON-LD): 6842 CV
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-arnhem-11858. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Pleyade (Plaatsen: None, Postcode: 6842 CV)
#
# Verwerken item 11/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-heteren-15138
#   -> Gevonden postcode (JSON-LD): 6666 BR
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-heteren-15138. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Stichting Samen Zorgen (Plaatsen: None, Postcode: 6666 BR)
#
# Verwerken item 12/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-t-jagthuis-velp-12707
#   -> Gevonden postcode (JSON-LD): 6881 TA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-t-jagthuis-velp-12707. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Innoforte, 't Jagthuis (Plaatsen: None, Postcode: 6881 TA)
#
# Verwerken item 13/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-charim-locatie-de-tollekamp-rhenen-12794
#   -> Gevonden postcode (JSON-LD): 3911 ND
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-charim-locatie-de-tollekamp-rhenen-12794/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Charim, locatie De Tollekamp (Plaatsen: None, Postcode: 3911 ND)
#
# Verwerken item 14/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-verpleeghuis-walraven-bennekom-3048839
#   -> Gevonden postcode (JSON-LD): 6721 PG
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-verpleeghuis-walraven-bennekom-3048839/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 73
#   -> Data verzameld voor: Opella Verpleeghuis Walraven (Plaatsen: 73, Postcode: 6721 PG)
#
# Verwerken item 15/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-mooi-land-doorwerth-10005659
#   -> Gevonden postcode (JSON-LD): 6865 CK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-mooi-land-doorwerth-10005659/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 40
#   -> Data verzameld voor: Vilente Mooi-Land (Plaatsen: 40, Postcode: 6865 CK)
#
# Verwerken item 16/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-de-lookant-wanroij-13537
#   -> Gevonden postcode (JSON-LD): 5446 BG
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-de-lookant-wanroij-13537/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein De Lookant (Plaatsen: None, Postcode: 5446 BG)
#
# Verwerken item 17/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-arnhem-11859
#   -> Gevonden postcode (JSON-LD): 6811 EZ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-arnhem-11859. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: DrieGasthuizenGroep (Plaatsen: None, Postcode: 6811 EZ)
#
# Verwerken item 18/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-zevenaar-14695
#   -> Gevonden postcode (JSON-LD): 6903 ZN
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-zevenaar-14695. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije (Plaatsen: None, Postcode: 6903 ZN)
#
# Verwerken item 19/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-rumah-kita-wageningen-3020924
#   -> Gevonden postcode (JSON-LD): 6708 AL
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-rumah-kita-wageningen-3020924/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 160
#   -> Data verzameld voor: Zinzia Zorggroep, Verpleeghuis Rumah Kita (Plaatsen: 160, Postcode: 6708 AL)
#
# Verwerken item 20/20 op pagina 2...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-droostaete-duiven-3041809
#   -> Gevonden postcode (JSON-LD): 6921 WJ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-droostaete-duiven-3041809. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, Droostaete (Plaatsen: None, Postcode: 6921 WJ)
#
# Einde pagina 2, pauzeren (2s)...
#
# --- Scraping pagina 3 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina3?d=25
# Aantal resultaten gevonden op deze pagina: 20
#
# Verwerken item 1/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-nijmegen-8321
#   -> Gevonden postcode (JSON-LD): 6523 PA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-nijmegen-8321. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: De Waalboog (Plaatsen: None, Postcode: 6523 PA)
#
# Verwerken item 2/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-zorgcentrum-huize-rosa-nijmegen-10000333
#   -> Gevonden postcode (JSON-LD): 6543 JG
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-zorgcentrum-huize-rosa-nijmegen-10000333. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Stichting Zorgcentrum Huize Rosa (Plaatsen: None, Postcode: 6543 JG)
#
# Verwerken item 3/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-st-elisabeth-beneden-leeuwen-14675
#   -> Gevonden postcode (JSON-LD): 6658 WX
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-st-elisabeth-beneden-leeuwen-14675. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: zorggroep Maas en Waal, locatie St. Elisabeth (Plaatsen: None, Postcode: 6658 WX)
#
# Verwerken item 4/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-castella-cuijk-3059123
#   -> Gevonden postcode (JSON-LD): 5431 MC
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-castella-cuijk-3059123/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein Castella (Plaatsen: None, Postcode: 5431 MC)
#
# Verwerken item 5/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-zorgcentrum-liefkenshoek-heteren-12644
#   -> Gevonden postcode (JSON-LD): 6666 BR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-stichting-samen-zorgen-zorgcentrum-liefkenshoek-heteren-12644/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Stichting Samen Zorgen, Zorgcentrum Liefkenshoek (Plaatsen: None, Postcode: 6666 BR)
#
# Verwerken item 6/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-oosterwolde-velp-12709
#   -> Gevonden postcode (JSON-LD): 6883 JK
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-oosterwolde-velp-12709. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Innoforte, Oosterwolde (Plaatsen: None, Postcode: 6883 JK)
#
# Verwerken item 7/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-nijevelt-nijmegen-12670
#   -> Gevonden postcode (JSON-LD): 6525 AH
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-nijevelt-nijmegen-12670/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 86
#   -> Data verzameld voor: De Waalboog, locatie Nijevelt (Plaatsen: 86, Postcode: 6525 AH)
#
# Verwerken item 8/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-de-kasteelhof-druten-12604
#   -> Gevonden postcode (JSON-LD): 6651 VB
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-de-kasteelhof-druten-12604/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Zorggroep Maas en Waal, locatie De Kasteelhof (Plaatsen: None, Postcode: 6651 VB)
#
# Verwerken item 9/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-waalstaete-arnhem-12575
#   -> Gevonden postcode (JSON-LD): 6826 BR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-waalstaete-arnhem-12575/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pleyade, locatie Waalstaete (Plaatsen: None, Postcode: 6826 BR)
#
# Verwerken item 10/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-woon-en-zorgcentrum-de-nudehof-wageningen-12715
#   -> Gevonden postcode (JSON-LD): 6702 BR
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-woon-en-zorgcentrum-de-nudehof-wageningen-12715/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Opella Woon- en zorgcentrum De Nudehof (Plaatsen: None, Postcode: 6702 BR)
#
# Verwerken item 11/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-obg-nijmegen-10017078
#   -> Gevonden postcode (JSON-LD): 6524 PJ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-obg-nijmegen-10017078. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: OBG (Plaatsen: None, Postcode: 6524 PJ)
#
# Verwerken item 12/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-alde-steeg-beuningen-12586
#   -> Gevonden postcode (JSON-LD): 6641 BG
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-locatie-alde-steeg-beuningen-12586/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: zorggroep Maas en Waal, locatie Alde Steeg (Plaatsen: None, Postcode: 6641 BG)
#
# Verwerken item 13/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-op-t-hoogveld-sint-anthonis-13487
#   -> Gevonden postcode (JSON-LD): 5845 DZ
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-op-t-hoogveld-sint-anthonis-13487/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein Op 't Hoogveld (Plaatsen: None, Postcode: 5845 DZ)
#
# Verwerken item 14/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-drie-gasthuizen-arnhem-13299
#   -> Gevonden postcode (JSON-LD): 6824 KK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-drie-gasthuizen-arnhem-13299/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 132
#   -> Data verzameld voor: DrieGasthuizenGroep, Woonzorgcentrum Drie Gasthuizen (Plaatsen: 132, Postcode: 6824 KK)
#
# Verwerken item 15/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentra-pantein-beugen-12262
#   -> Gevonden postcode (JSON-LD): 5835 DV
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentra-pantein-beugen-12262. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Zorgcentra Pantein (Plaatsen: None, Postcode: 5835 DV)
#
# Verwerken item 16/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-lorentzhuis-velp-12708
#   -> Gevonden postcode (JSON-LD): 6882 LR
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-lorentzhuis-velp-12708. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Innoforte, Lorentzhuis (Plaatsen: None, Postcode: 6882 LR)
#
# Verwerken item 17/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-zevenaar-zevenaar-3041808
#   -> Gevonden postcode (JSON-LD): 6903 ZN
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-zevenaar-zevenaar-3041808. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, Zevenaar (Plaatsen: None, Postcode: 6903 ZN)
#
# Verwerken item 18/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-la-verna-wijchen-12731
#   -> Gevonden postcode (JSON-LD): 6603 AM
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-la-verna-wijchen-12731/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 70
#   -> Data verzameld voor: De Waalboog, locatie La Verna (Plaatsen: 70, Postcode: 6603 AM)
#
# Verwerken item 19/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-de-biesdel-velp-12706
#   -> Gevonden postcode (JSON-LD): 6881 CD
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-de-biesdel-velp-12706/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 52
#   -> Data verzameld voor: Innoforte, De Biesdel (Plaatsen: 52, Postcode: 6881 CD)
#
# Verwerken item 20/20 op pagina 3...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-joachim-en-anna-nijmegen-17470
#   -> Gevonden postcode (JSON-LD): 6523 PA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-de-waalboog-locatie-joachim-en-anna-nijmegen-17470/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 167
#   -> Data verzameld voor: De Waalboog, locatie Joachim en Anna (Plaatsen: 167, Postcode: 6523 PA)
#
# Einde pagina 3, pauzeren (2s)...
#
# --- Scraping pagina 4 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina4?d=25
# Aantal resultaten gevonden op deze pagina: 20
#
# Verwerken item 1/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-vegetarisch-zorgcentrum-felixoord-oosterbeek-12681
#   -> Gevonden postcode (JSON-LD): 6861 CH
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-vegetarisch-zorgcentrum-felixoord-oosterbeek-12681/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Vilente, Vegetarisch Zorgcentrum Felixoord (Plaatsen: None, Postcode: 6861 CH)
#
# Verwerken item 2/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-velp-11909
#   -> Gevonden postcode (JSON-LD): 6881 TA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-velp-11909. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Innoforte (Plaatsen: None, Postcode: 6881 TA)
#
# Verwerken item 3/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-meulenvelden-didam-12593
#   -> Gevonden postcode (JSON-LD): 6942 RG
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-meulenvelden-didam-12593. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, Meulenvelden (Plaatsen: None, Postcode: 6942 RG)
#
# Verwerken item 4/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-laverhof-locatie-het-retraitehuis-uden-13517
#   -> Gevonden postcode (JSON-LD): 5405 NA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-laverhof-locatie-het-retraitehuis-uden-13517/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 55
#   -> Data verzameld voor: Laverhof, locatie Het Retraitehuis (Plaatsen: 55, Postcode: 5405 NA)
#
# Verwerken item 5/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-sint-anna-boxmeer-12189
#   -> Gevonden postcode (JSON-LD): 5831 JM
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-sint-anna-boxmeer-12189. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Sint Anna (Plaatsen: None, Postcode: 5831 JM)
#
# Verwerken item 6/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-obg-verpleeghuiszorg-nijmegen-10017077
#   -> Gevonden postcode (JSON-LD): 6524 PJ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-obg-verpleeghuiszorg-nijmegen-10017077. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: OBG, Verpleeghuiszorg (Plaatsen: None, Postcode: 6524 PJ)
#
# Verwerken item 7/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-symfonie-boxmeer-13354
#   -> Gevonden postcode (JSON-LD): 5831 ZZ
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-symfonie-boxmeer-13354/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein Symfonie (Plaatsen: None, Postcode: 5831 ZZ)
#
# Verwerken item 8/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-zzg-herstelcentrum-groesbeek-3047546
#   -> Gevonden postcode (JSON-LD): 6561 LE
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-zzg-herstelcentrum-groesbeek-3047546/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 180
#   -> Data verzameld voor: ZZG zorggroep, ZZG Herstelcentrum (Plaatsen: 180, Postcode: 6561 LE)
#
# Verwerken item 9/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-wageningen-11901
#   -> Gevonden postcode (JSON-LD): 6704 AV
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-wageningen-11901. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Zinzia Zorggroep (Plaatsen: None, Postcode: 6704 AV)
#
# Verwerken item 10/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-verpleeghuis-heijendaal-arnhem-14665
#   -> Gevonden postcode (JSON-LD): 6812 AX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-verpleeghuis-heijendaal-arnhem-14665/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 124
#   -> Data verzameld voor: DrieGasthuizenGroep, Verpleeghuis Heijendaal (Plaatsen: 124, Postcode: 6812 AX)
#
# Verwerken item 11/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-hamerstaete-westervoort-3058249
#   -> Gevonden postcode (JSON-LD): 6931 EV
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-hamerstaete-westervoort-3058249. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, Hamerstaete (Plaatsen: None, Postcode: 6931 EV)
#
# Verwerken item 12/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-heukelumshof-pannerden-3041810
#   -> Gevonden postcode (JSON-LD): 6911 AX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-heukelumshof-pannerden-3041810/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 19
#   -> Data verzameld voor: Liemerije, Heukelumshof (Plaatsen: 19, Postcode: 6911 AX)
#
# Verwerken item 13/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-locatie-insula-dei-arnhem-12571
#   -> Gevonden postcode (JSON-LD): 6824 HK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-locatie-insula-dei-arnhem-12571/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: DrieGasthuizenGroep, locatie Insula Dei (Plaatsen: None, Postcode: 6824 HK)
#
# Verwerken item 14/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-norbertushof-gennep-15017
#   -> Gevonden postcode (JSON-LD): 6591 KH
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-norbertushof-gennep-15017/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein Norbertushof (Plaatsen: None, Postcode: 6591 KH)
#
# Verwerken item 15/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-oranje-nassau-s-oord-wageningen-14689
#   -> Gevonden postcode (JSON-LD): 6704 AV
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-oranje-nassau-s-oord-wageningen-14689/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 181
#   -> Data verzameld voor: Zinzia Zorggroep, Verpleeghuis Oranje Nassau's Oord (Plaatsen: 181, Postcode: 6704 AV)
#
# Verwerken item 16/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-aldenhorst-mill-13451
#   -> Gevonden postcode (JSON-LD): 5451 PA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pantein-aldenhorst-mill-13451/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pantein Aldenhorst (Plaatsen: None, Postcode: 5451 PA)
#
# Verwerken item 17/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-vreedenhoff-arnhem-12574
#   -> Gevonden postcode (JSON-LD): 6824 LV
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-innoforte-vreedenhoff-arnhem-12574/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 196
#   -> Data verzameld voor: Innoforte, Vreedenhoff (Plaatsen: 196, Postcode: 6824 LV)
#
# Verwerken item 18/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-herstelkliniek-pantein-boxmeer-14862
#   -> Gevonden postcode (JSON-LD): 5831 LL
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-herstelkliniek-pantein-boxmeer-14862/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Herstelkliniek Pantein (Plaatsen: None, Postcode: 5831 LL)
#
# Verwerken item 19/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-locatie-huize-kohlmann-arnhem-12572
#   -> Gevonden postcode (JSON-LD): 6811 DW
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-locatie-huize-kohlmann-arnhem-12572/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: DrieGasthuizenGroep, locatie Huize Kohlmann (Plaatsen: None, Postcode: 6811 DW)
#
# Verwerken item 20/20 op pagina 4...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-malderburch-centrum-voor-welzijn-wonen-en-zorg-malden-12655
#   -> Gevonden postcode (JSON-LD): 6581 AE
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-malderburch-centrum-voor-welzijn-wonen-en-zorg-malden-12655/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Malderburch, Centrum voor Welzijn, Wonen en Zorg (Plaatsen: None, Postcode: 6581 AE)
#
# Einde pagina 4, pauzeren (2s)...
#
# --- Scraping pagina 5 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina5?d=25
# Aantal resultaten gevonden op deze pagina: 20
#
# Verwerken item 1/20 op pagina 5...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-de-lingehof-bemmel-14674
#   -> Gevonden postcode (JSON-LD): 6681 WP
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-de-lingehof-bemmel-14674/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 143
#   -> Data verzameld voor: Zinzia Zorggroep, Verpleeghuis De Lingehof (Plaatsen: 143, Postcode: 6681 WP)
#
# Verwerken item 2/20 op pagina 5...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-de-rijnhof-renkum-12688
#   -> Gevonden postcode (JSON-LD): 6871 AM
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zinzia-zorggroep-verpleeghuis-de-rijnhof-renkum-12688/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 40
#   -> Data verzameld voor: Zinzia Zorggroep, Verpleeghuis De Rijnhof (Plaatsen: 40, Postcode: 6871 AM)
#
# Verwerken item 3/20 op pagina 5...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-maasland-herpen-13426
#   -> Gevonden postcode (JSON-LD): 5373 AD
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-maasland-herpen-13426/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, Maasland (Plaatsen: None, Postcode: 5373 AD)
#
# ...
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Attent Zorg en Behandeling, Rhederhof (Plaatsen: None, Postcode: 6991 DV)
#
# Verwerken item 3/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-overdal-doorwerth-12684
#   -> Gevonden postcode (JSON-LD): 6865 CK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-vilente-overdal-doorwerth-12684/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 44
#   -> Data verzameld voor: Vilente Overdal (Plaatsen: 44, Postcode: 6865 CK)
#
# Verwerken item 4/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-polderhof-arnhem-3028848
#   -> Gevonden postcode (JSON-LD): 6833 CK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-polderhof-arnhem-3028848/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: Pleyade, locatie Polderhof (Plaatsen: None, Postcode: 6833 CK)
#
# Verwerken item 5/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-katwijk-oss-17481
#   -> Gevonden postcode (JSON-LD): 5341 HB
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-katwijk-oss-17481/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, Katwijk (Plaatsen: None, Postcode: 5341 HB)
#
# Verwerken item 6/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-westerkade-arnhem-3062170
#   -> Gevonden postcode (JSON-LD): 6827 AS
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-driegasthuizengroep-woonzorgcentrum-westerkade-arnhem-3062170/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 30
#   -> Data verzameld voor: DrieGasthuizenGroep, Woonzorgcentrum Westerkade (Plaatsen: 30, Postcode: 6827 AS)
#
# Verwerken item 7/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-dijkzicht-tolkamer-3041813
#   -> Gevonden postcode (JSON-LD): 6916 CA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-liemerije-dijkzicht-tolkamer-3041813. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Liemerije, Dijkzicht (Plaatsen: None, Postcode: 6916 CA)
#
# Verwerken item 8/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-verpleegunit-de-hulsen-nijmegen-3035482
#   -> Gevonden postcode (JSON-LD): 6525 EB
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-verpleegunit-de-hulsen-nijmegen-3035482/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: zorggroep Maas en Waal, Verpleegunit de Hulsen (Plaatsen: None, Postcode: 6525 EB)
#
# Verwerken item 9/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-de-wilberthof-berghem-13347
#   -> Gevonden postcode (JSON-LD): 5351 EV
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-de-wilberthof-berghem-13347/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, De Wilberthof (Plaatsen: None, Postcode: 5351 EV)
#
# Verwerken item 10/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-klein-waelwick-ewijk-10023829
#   -> Gevonden postcode (JSON-LD): 6644 CP
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorggroep-maas-en-waal-klein-waelwick-ewijk-10023829. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: zorggroep Maas en Waal, Klein Waelwick (Plaatsen: None, Postcode: 6644 CP)
#
# Verwerken item 11/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-elst-wijchen-3063300
#   -> Gevonden postcode (JSON-LD): 6601 AT
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-elst-wijchen-3063300/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 20
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie De Elst (Plaatsen: 20, Postcode: 6601 AT)
#
# Verwerken item 12/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-verpleeghuis-machtella-bennekom-3041759
#   -> Gevonden postcode (JSON-LD): 6721 PK
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-opella-verpleeghuis-machtella-bennekom-3041759/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 30
#   -> Data verzameld voor: Opella Verpleeghuis Machtella (Plaatsen: 30, Postcode: 6721 PK)
#
# Verwerken item 13/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-weegbree-wijchen-15016
#   -> Gevonden postcode (JSON-LD): 6601 GV
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-weegbree-wijchen-15016/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 72
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie De Weegbree (Plaatsen: 72, Postcode: 6601 GV)
#
# Verwerken item 14/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-boszicht-nijmegen-12665
#   -> Gevonden postcode (JSON-LD): 6525 TJ
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-boszicht-nijmegen-12665/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 92
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie Boszicht (Plaatsen: 92, Postcode: 6525 TJ)
#
# Verwerken item 15/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-corte-foort-oss-3059935
#   -> Gevonden postcode (JSON-LD): 5342 JW
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-brabantzorg-corte-foort-oss-3059935/faciliteiten
#   -> Rij 'Aantal plaatsen totaal' niet gevonden in de tabel(len) 'Aantal plekken en wachttijd'.
#   -> Data verzameld voor: BrabantZorg, Corte Foort (Plaatsen: None, Postcode: 5342 JW)
#
# Verwerken item 16/20 op pagina 8...
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-prinses-irenestraat-elst-10014173
#   -> Gevonden postcode (JSON-LD): 6661 EA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-pleyade-locatie-prinses-irenestraat-elst-10014173. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Pleyade, locatie Prinses Irenestraat (Plaatsen: None, Postcode: 6661 EA)
#
# Verwerken item 17/20 op pagina 8...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor Dagelijks Leven, locatie Het Elderomhuis.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-dagelijks-leven-locatie-het-elderomhuis-boxmeer-10083499
#   -> Gevonden postcode (JSON-LD): 5831 TX
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-dagelijks-leven-locatie-het-elderomhuis-boxmeer-10083499. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Dagelijks Leven, locatie Het Elderomhuis (Plaatsen: None, Postcode: 5831 TX)
#
# Verwerken item 18/20 op pagina 8...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor Missiehuis Vrijland.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-missiehuis-vrijland-oosterbeek-11897
#   -> Gevonden postcode (JSON-LD): 6861 WJ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-missiehuis-vrijland-oosterbeek-11897. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Missiehuis Vrijland (Plaatsen: None, Postcode: 6861 WJ)
#
# Verwerken item 19/20 op pagina 8...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor Zorgcentrum Anker, locatie Avondrust.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-locatie-avondrust-opheusden-10085336
#   -> Gevonden postcode (JSON-LD): 4043 MA
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zorgcentrum-anker-locatie-avondrust-opheusden-10085336. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: Zorgcentrum Anker, locatie Avondrust (Plaatsen: None, Postcode: 4043 MA)
#
# Verwerken item 20/20 op pagina 8...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG Zorggroep, Woonlocatie Bosrijk.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-bosrijk-nijmegen-10008324
#   -> Gevonden postcode (JSON-LD): 6525 TJ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-bosrijk-nijmegen-10008324. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: ZZG Zorggroep, Woonlocatie Bosrijk (Plaatsen: None, Postcode: 6525 TJ)
#
# Einde pagina 8, pauzeren (2s)...
#
# --- Scraping pagina 9 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina9?d=25
# Aantal resultaten gevonden op deze pagina: 6
#
# Verwerken item 1/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonlocatie De Horizon.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-horizon-nijmegen-3062290
#   -> Gevonden postcode (JSON-LD): 6537 GA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-horizon-nijmegen-3062290/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 48
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie De Horizon (Plaatsen: 48, Postcode: 6537 GA)
#
# Verwerken item 2/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonlocatie De Oogst.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-oogst-wijchen-3059115
#   -> Gevonden postcode (JSON-LD): 6601 AT
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-oogst-wijchen-3059115/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 46
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie De Oogst (Plaatsen: 46, Postcode: 6601 AT)
#
# Verwerken item 3/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonlocatie De Plataan.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-plataan-groesbeek-3058582
#   -> Gevonden postcode (JSON-LD): 6561 LA
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-de-plataan-groesbeek-3058582/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 23
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie De Plataan (Plaatsen: 23, Postcode: 6561 LA)
#
# Verwerken item 4/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonlocatie Griffioen.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-griffioen-nijmegen-3059390
#   -> Gevonden postcode (JSON-LD): 6541 RX
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-griffioen-nijmegen-3059390/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 78
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie Griffioen (Plaatsen: 78, Postcode: 6541 RX)
#
# Verwerken item 5/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonlocatie Mookerplein.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-mookerplein-mook-10013147
#   -> Gevonden postcode (JSON-LD): 6585 KZ
#   -> 'Faciliteiten' link niet gevonden op https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonlocatie-mookerplein-mook-10013147. Kan aantal plaatsen niet ophalen.
#   -> Data verzameld voor: ZZG zorggroep, Woonlocatie Mookerplein (Plaatsen: None, Postcode: 6585 KZ)
#
# Verwerken item 6/6 op pagina 9...
#   - Waarschuwing: Kon cijfer '-' niet converteren voor ZZG zorggroep, Woonzorglocatie Kloostertuin.
#   -> Detailpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonzorglocatie-kloostertuin-groesbeek-3048432
#   -> Gevonden postcode (JSON-LD): 6561 BZ
#   -> Faciliteitenpagina ophalen: https://www.zorgkaartnederland.nl/zorginstelling/verpleeghuis-en-verzorgingshuis-zzg-zorggroep-woonzorglocatie-kloostertuin-groesbeek-3048432/faciliteiten
#   -> Correcte tabel gevonden ('Aantal plekken en wachttijd').
#   -> Gevonden aantal plaatsen totaal: 32
#   -> Data verzameld voor: ZZG zorggroep, Woonzorglocatie Kloostertuin (Plaatsen: 32, Postcode: 6561 BZ)
#
# Einde pagina 9, pauzeren (2s)...
#
# --- Scraping pagina 10 voor Nijmegen ---
# Pagina URL: https://www.zorgkaartnederland.nl/verpleeghuis-en-verzorgingshuis/nijmegen/pagina10?d=25
# Geen resultaten (items) meer gevonden op pagina 10. Stoppen met pagineren.
#
# ============================================================
# Scrapen voltooid in 268.83 seconden.
# Totaal 166 instellingen gevonden en verwerkt voor Nijmegen.
# ============================================================
#
# Data succesvol opgeslagen in bestand: zorginstellingen_nijmegen_w_beds_pc.json
